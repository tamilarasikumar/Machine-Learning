# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("DATASET.csv")

# %%
dataFrame = pd.DataFrame(df.head(), columns=["CustomerID","tenure"])
dataFrame.plot(x="CustomerID", y="tenure", kind="bar", figsize=(10, 6))
plt.show()

# %%
sns.distplot(df['tenure'], color='g')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tenure', ylabel='Density'>

# %%
sns.distplot(df['tenure'], kde= False)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tenure'>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='gender', palette='coolwarm')

# %%
df.head(20)
sns.catplot(x="gender",y="tenure",data=df)
sns.catplot(x="gender",y="tenure",kind="violin",data=df)
sns.catplot(x="gender",y="tenure",kind="boxen",data=df)

# %%
from io import StringIO
import pandas as pd
from google.cloud import storage,bigquery
client=storage.Client()
bucket=client.get_bucket("bucket1_dataset")
blob=bucket.get_blob(f"dataset.csv")
bt=blob.download_as_string()
# print(bt)
s=str(bt,"utf-8")
s=StringIO(s)
df=pd.read_csv(s)
df
