# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from google.cloud import storage
import statistics as st
from io import StringIO
from google.cloud import bigquery

# %%
# %%bigquery
# SELECT * FROM `stalwart-cable-335111.dataset_bucket.dataset_csv`
# Out:
# ...
# Downloading: 100%|██████████| 7043/7043 [00:01<00:00, 4303.97rows/s]
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     9732-OUYRN  Female              0     True       False      49
# 1     0661-KQHNK  Female              0     True        True       6
# 2     4709-LKHYG  Female              0     True        True      29
# 3     9824-QCJPK    Male              0     True       False      36
# 4     4716-MRVEN  Female              0    False       False      29
# ...          ...     ...            ...      ...         ...     ...
# 7038  5883-GTGVD    Male              0    False       False      19
# 7039  5502-RLUYV  Female              0     True        True      69
# 7040  3001-UNBTL    Male              1     True        True      29
# 7041  5760-IFJOZ    Male              0    False       False       3
# 7042  2081-VEYEH    Male              0    False       False       3
#
# ...

# %%
# %%bigquery
# SELECT * FROM `stalwart-cable-335111.dataset_bucket.dataset_csv` where gender like 'M%'
# Out:
# ...
# Downloading: 100%|██████████| 3555/3555 [00:01<00:00, 1800.62rows/s]
#       customerID gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     9824-QCJPK   Male              0     True       False      36
# 1     4323-ELYYB   Male              0     True        True      13
# 2     1269-FOYWN   Male              0     True        True      44
# 3     1401-FTHFQ   Male              0     True        True      23
# 4     6814-ZPWFQ   Male              1    False       False      51
# ...          ...    ...            ...      ...         ...     ...
# 3550  1571-SAVHK   Male              0    False       False      12
# 3551  5883-GTGVD   Male              0    False       False      19
# 3552  3001-UNBTL   Male              1     True        True      29
# 3553  5760-IFJOZ   Male              0    False       False       3
# 3554  2081-VEYEH   Male              0    False       False       3
#
#       PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# ...

# %%
# %%bigquery
# SELECT * FROM `stalwart-cable-335111.dataset_bucket.dataset_csv` where tenure >50
# Out:
# ...
# Downloading: 100%|██████████| 2105/2105 [00:01<00:00, 1186.25rows/s]
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     6814-ZPWFQ    Male              1    False       False      51
# 1     9830-ECLEN    Male              0     True        True      58
# 2     6229-UOLQL    Male              0     True        True      56
# 3     3605-JISKB    Male              1     True       False      55
# 4     1088-CNNKB    Male              0     True       False      63
# ...          ...     ...            ...      ...         ...     ...
# 2100  6211-WHMYA  Female              1    False       False      64
# 2101  8548-AWOFC    Male              0     True       False      66
# 2102  9943-VSZUV    Male              1    False       False      67
# 2103  7821-DPRQE    Male              0     True       False      68
# 2104  5502-RLUYV  Female              0     True        True      69
#
# ...

# %%
# %%bigquery
# SELECT * FROM `stalwart-cable-335111.dataset_bucket.dataset_csv` where paymentMethod='Mailed check' or paymentMethod='Electronic check'
# Out:
# ...
# Downloading: 100%|██████████| 3977/3977 [00:01<00:00, 2867.12rows/s]
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     4709-LKHYG  Female              0     True        True      29
# 1     9824-QCJPK    Male              0     True       False      36
# 2     4716-MRVEN  Female              0    False       False      29
# 3     8084-OIVBS  Female              0    False       False      11
# 4     4323-ELYYB    Male              0     True        True      13
# ...          ...     ...            ...      ...         ...     ...
# 3972  5883-GTGVD    Male              0    False       False      19
# 3973  5502-RLUYV  Female              0     True        True      69
# 3974  3001-UNBTL    Male              1     True        True      29
# 3975  5760-IFJOZ    Male              0    False       False       3
# 3976  2081-VEYEH    Male              0    False       False       3
#
# ...

# %%
# %%bigquery
# SELECT * FROM `stalwart-cable-335111.dataset_bucket.dataset_csv` order by tenure
# Out:
# ...
# Downloading: 100%|██████████| 7043/7043 [00:01<00:00, 6022.13rows/s]
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     2923-ARZLG    Male              0     True        True       0
# 1     2520-SGTTA  Female              0     True        True       0
# 2     3115-CZMZD    Male              0    False        True       0
# 3     4367-NUYAO    Male              0     True        True       0
# 4     2775-SEFEE    Male              0    False        True       0
# ...          ...     ...            ...      ...         ...     ...
# 7038  7663-YJHSN  Female              0     True       False      72
# 7039  9958-MEKUC    Male              0     True        True      72
# 7040  2193-SFWQW    Male              0     True        True      72
# 7041  9481-IEBZY    Male              1     True       False      72
# 7042  0129-KPTWJ    Male              0     True       False      72
#
# ...

# %%
# %%bigquery
# SELECT * FROM `stalwart-cable-335111.dataset_bucket.dataset_csv` order by tenure desc
# Out:
# ...
# Downloading: 100%|██████████| 7043/7043 [00:00<00:00, 7492.04rows/s]
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     5168-MQQCA  Female              0     True       False      72
# 1     5985-BEHZK  Female              1     True       False      72
# 2     3339-EAQNV    Male              1     True       False      72
# 3     3886-CERTZ  Female              0     True       False      72
# 4     8999-XXGNS  Female              1     True       False      72
# ...          ...     ...            ...      ...         ...     ...
# 7038  5709-LVOEQ  Female              0     True        True       0
# 7039  4472-LVYGI  Female              0     True        True       0
# 7040  4075-WKNIU  Female              0     True        True       0
# 7041  3213-VVOLG    Male              0     True        True       0
# 7042  7644-OMVMY    Male              0     True        True       0
#
# ...

# %%
# %%bigquery
# SELECT * FROM `stalwart-cable-335111.dataset_bucket.dataset_csv` WHERE Churn IS NULL
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 578.13query/s]
# Downloading: 0rows [00:01, ?rows/s]
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
# %%bigquery
# SELECT MIN(MonthlyCharges) AS SmallestPrice from`stalwart-cable-335111.dataset_bucket.dataset_csv`
# Out:
# ...
# Downloading: 100%|██████████| 1/1 [00:01<00:00,  1.91s/rows]
#    SmallestPrice
# 0          18.25

# %%
# %%bigquery
# SELECT Max(MonthlyCharges) AS LargestPrice from`stalwart-cable-335111.dataset_bucket.dataset_csv`
# Out:
# ...
# Downloading: 100%|██████████| 1/1 [00:01<00:00,  1.11s/rows]
#    LargestPrice
# 0        118.75

# %%
# %%bigquery
# SELECT SUM(MonthlyCharges) AS Sum from`stalwart-cable-335111.dataset_bucket.dataset_csv`
# Out:
# ...
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  1.09rows/s]
#         Sum
# 0  456116.6

# %%
# %%bigquery
# SELECT AVG(MonthlyCharges) AS Average from`stalwart-cable-335111.dataset_bucket.dataset_csv`
# Out:
# ...
# Downloading: 100%|██████████| 1/1 [00:00<00:00,  1.04rows/s]
#      Average
# 0  64.761692

# %%
# %%bigquery
# SELECT COUNT(MonthlyCharges) AS Count from`stalwart-cable-335111.dataset_bucket.dataset_csv`
# Out:
# ...
# Downloading: 100%|██████████| 1/1 [00:01<00:00,  1.11s/rows]
#    Count
# 0   7043

# %%
client=storage.Client()
bucket=client.get_bucket("bucket1_dataset")
blob=bucket.get_blob(f"dataset.csv")
bt=blob.download_as_string()
# print(bt)
s=str(bt,"utf-8")
s=StringIO(s)
df=pd.read_csv(s)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             NaN  No phone service             DSL             No  ...
# ...

# %%
bigquery_client = bigquery.Client()
QUERY="""
SELECT*FROM `stalwart-cable-335111.dataset_bucket.dataset_csv` 
"""
query_job=bigquery_client.query(QUERY)
df=query_job.to_dataframe()
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  9732-OUYRN  Female              0     True       False      49
# 1  0661-KQHNK  Female              0     True        True       6
# 2  4709-LKHYG  Female              0     True        True      29
# 3  9824-QCJPK    Male              0     True       False      36
# 4  4716-MRVEN  Female              0    False       False      29
#
#   PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 0         True            No              No  No internet service  ...
# 1         True            No              No  No internet service  ...
# 2         True            No              No  No internet service  ...
# 3         True            No              No  No internet service  ...
# 4         True            No              No  No internet service  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
df.rename(columns = {'customerID':'CustomerID'}, inplace = True)
print(df)
# Out:
#       CustomerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     9732-OUYRN  Female              0     True       False      49
# 1     0661-KQHNK  Female              0     True        True       6
# 2     4709-LKHYG  Female              0     True        True      29
# 3     9824-QCJPK    Male              0     True       False      36
# 4     4716-MRVEN  Female              0    False       False      29
# ...          ...     ...            ...      ...         ...     ...
# 7038  5883-GTGVD    Male              0    False       False      19
# 7039  5502-RLUYV  Female              0     True        True      69
# 7040  3001-UNBTL    Male              1     True        True      29
# 7041  5760-IFJOZ    Male              0    False       False       3
# 7042  2081-VEYEH    Male              0    False       False       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# ...

# %%
df.loc[1:5, ['CustomerID', 'PhoneService', 'PaperlessBilling']]
# Out:
#    CustomerID  PhoneService  PaperlessBilling
# 1  0661-KQHNK          True             False
# 2  4709-LKHYG          True             False
# 3  9824-QCJPK          True             False
# 4  4716-MRVEN          True             False
# 5  8084-OIVBS          True             False

# %%
dataFrame = pd.DataFrame(df.head(), columns=["CustomerID","tenure"])
dataFrame.plot(x="CustomerID", y="tenure", kind="bar", figsize=(10, 6))
plt.show()

# %%
Female = df.loc[df['gender'] == 'Female'].count()[0]
Male = df.loc[df['gender'] == 'Male'].count()[0]
#plt.pie([yes, no])
plt.style.use('ggplot')
labels = ['Female', 'Male']
colors = ['#abcdef', '#00FF00']
explode=[0.2,0]
plt.pie([Female, Male], labels = labels, autopct='%1.1f%%', colors =colors,startangle=90,explode=explode,shadow=True)
plt.title('gender')
plt.legend(title="gender")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
stats_df = df.drop(['tenure', 'SeniorCitizen', 'Partner'], axis=1)
sns.boxplot(data=stats_df)
# Out:
# <AxesSubplot:>
